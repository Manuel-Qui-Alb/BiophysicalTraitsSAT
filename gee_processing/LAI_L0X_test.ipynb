# %%
import ee
import geemap
import gee.gee_objects as gee
ee.Initialize(project='saw-ucdavis')

# %%
# print(collection.size().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
image = collection.first()
geo = image.geometry()

Map = geemap.Map()

Map.centerObject(vector_RIP720, 12)
Map.addLayer(image, {'bands': 'LAI', 'min': 0,'max': 200, 'palette': ['red', 'orange', 'yellow', 'darkgreen', 'darkgreen']})
# Map.addLayer(geo)
Map
# col.count().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[36.84941819235097, -120.17574403015209], controls=(WidgetControl(options=['position', 'transparent…

# %%
geo
